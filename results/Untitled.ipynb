# %%
#!/usr/bin/env python
# coding: utf-8
import datetime
import hashlib
import json
import requests
from uuid import uuid4
from urllib.parse import urlparse
from flask import Flask,jsonify,request
import Blockchain
blockchain = Blockchain.create_blockchain()
app = Flask(__name__)
node_address = str(uuid4()).replace('-','')

# %%
import time

# %%
@app.route('/broadcast_chain' , methods = ['POST'])
def broadcast_chain():
    temp_block = request.get_json().get('temp_block')
    previous_block = blockchain.get_previous_block()
    previous_hash = blockchain.hash(previous_block)
    block = {'index' : len(blockchain.chain) +1 ,
            'timestamp' : str(datetime.datetime.now()) ,
            'proof' : temp_block['proof'],
            'previous_hash' : previous_hash,
            'transactions' : temp_block['transactions']}
    blockchain.chain.append(block)
    response = {'message' : f'This transaction will be added to Block '}
    return jsonify(response),201

# %%
@app.route('/mine_block' , methods = ['GET'])
def mine_block():
    
    start = time.time()
    previous_block = blockchain.get_previous_block()
    previous_proof = previous_block['proof']
    proof = blockchain.proof_of_work(previous_proof)
    previous_hash = blockchain.hash(previous_block)
    block = blockchain.create_block(proof,previous_hash)
    response = {'message' : 'Congratulations, You just mined a block!',
               'index' : block['index'],
               'timestamp' : block['timestamp'],
               'proof' : block['proof'],
               'previous_hash' : block['previous_hash'],
               'transactions' : block['transactions']}
    end = time.time()
    
    response = {'start' : start,
               'end' : end}
    
    """
    for node in blockchain.nodes:       
        temp_block = {'temp_block':block}
        URL = str('http://')+node+"/broadcast_chain"        
        try:
            _ = requests.post(URL, json=temp_block)
        except:
            pass
    
    """
    return jsonify(response),200

# %%
@app.route('/get_chain' , methods = ['GET'])
def get_chain():
    response = {'chain' : blockchain.chain,
               'length' : len(blockchain.chain)}
    return jsonify(response),200

# %%
@app.route('/is_valid' , methods = ['GET'])
def is_valid():
    is_valid = blockchain.is_chain_valid(blockchain.chain)
    if is_valid == 2:
        response = {'message' : "Your Blockchain is valid!"}
    elif is_valid ==0:
        response = {'message' : "We have a problem! Previous Hash invalid!!!"}
    else:
        response = {'message' : "We have a problem! Proof invalid!!!"}
    return jsonify(response),200

# %%
@app.route('/add_transaction' , methods = ['POST'])
def add_transaction():
    start = time.time()
    json = request.get_json()
    transaction_keys = ['sender', 'receiver', 'amount','category']
    if not all (key in json for key in transaction_keys):
        return 'Some elements of the transactions are missing!',400
    index = blockchain.add_transaction(json['sender'], json['receiver'], json['amount'],json['category'])
    end = time.time()
    #response = {'message' : f'This transaction will be added to Block {index}'}
    
    response = {'start' : start,
               'end' : end }
    
    #res = mine_block()
    return jsonify(response),201

# %%
@app.route('/connect_node' , methods = ['POST'])
def connect_node():
    json = request.get_json()
    nodes = json.get('nodes')
    if nodes is None:
        return "No node",400
    for node in nodes:
        blockchain.add_node(node)
    response = {'message' : 'All the nodes are now connected. The currency contains the following nodes : ',
               'total_nodes' : list(blockchain.nodes)}
    return jsonify(response),201

# %%
@app.route('/get_node' , methods = ['GET'])                                                                        
def get_nodes():
    response = {'message' : 'Connected nodes : ',
                'nodes' : list(blockchain.nodes)}
    return jsonify(response),200

# %%
@app.route('/replace_chain' , methods = ['GET'])
def replace_chain():
    is_chain_replaced = blockchain.replace_chain()
    if is_chain_replaced:
        response = {'message' : "The nodes had different chains, so the chain was replaced by the longest one!",
                   'new_chain' : blockchain.chain}
    else:
        response = {'message' : "All good! the chain is the largest one!",
                   'actual_chain' : blockchain.chain}
    return jsonify(response),200

# %%
@app.route('/find_transactions' , methods = ['POST'])
def find_transactions():
    json = request.get_json()
    user = json['user']
    if user is None:
        return "No User",400
    trans = [i['transactions'] for i in blockchain.chain][1:]
    info = []
    for i in trans:
        #print(i[0])
        if i[0]['sender'] == user or i[0]['receiver'] == user:

            info.append(i[0])
    if len(info) == 0:
        
        response = {'message' : 'You Had No Transactions So Far! '}
    else:
        response = {'message' : 'You Did the Following Transactions : ',
               'transactions' : list(info)}
    return jsonify(response),201

# %%
app.run(host='0.0.0.0',port = 5001)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5001/ (Press CTRL+C to quit)
# 127.0.0.1 - - [28/Apr/2020 13:41:02] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:05] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:07] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:09] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:11] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:13] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:15] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:17] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:20] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:22] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:24] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:26] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:28] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:31] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:33] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:35] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:37] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:39] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:42] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:44] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:46] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:49] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:51] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:54] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:56] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:41:58] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:00] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:02] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:04] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:07] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:09] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:11] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:14] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:16] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:18] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:20] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:22] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:25] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:27] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:29] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:31] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:33] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:36] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:38] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:40] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:43] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:45] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:47] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:49] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:52] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:55] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:57] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:42:59] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:02] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:04] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:06] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:09] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:11] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:13] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:15] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:18] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:20] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:22] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:25] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:27] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:29] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:31] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:34] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:36] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:38] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:40] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:42] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:45] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:47] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:49] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:51] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:54] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:56] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:43:58] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:00] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:02] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:05] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:07] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:10] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:12] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:14] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:16] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:19] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:21] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:23] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:26] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:28] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:30] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:33] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:35] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:37] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:39] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:42] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:44] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:46] "GET /mine_block HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2020 13:44:53] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:44:55] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:44:57] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:44:59] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:01] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:03] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:05] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:07] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:09] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:11] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:13] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:15] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:17] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:19] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:21] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:24] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:26] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:28] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:30] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:32] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:34] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:36] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:38] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:40] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:42] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:44] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:46] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:48] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:50] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:53] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:55] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:57] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:45:59] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:01] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:03] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:05] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:07] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:09] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:11] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:13] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:15] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:17] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:19] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:21] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:23] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:25] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:27] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:30] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:32] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:34] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:36] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:38] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:40] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:42] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:44] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:46] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:48] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:50] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:52] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:54] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:56] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:46:58] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:01] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:03] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:05] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:07] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:09] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:11] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:13] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:15] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:17] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:19] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:21] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:23] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:25] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:27] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:29] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:31] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:34] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:36] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:38] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:40] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:42] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:44] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:46] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:48] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:50] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:52] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:54] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:56] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:47:58] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:48:00] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:48:02] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:48:04] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:48:07] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:48:09] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:48:11] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:48:13] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:48:15] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 13:48:17] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 14:00:53] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 14:00:55] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 14:00:57] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 14:00:59] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 14:01:01] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 14:01:03] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 14:01:05] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 14:01:07] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 14:01:09] "POST /add_transaction HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Apr/2020 14:01:11] "POST /add_transaction HTTP/1.1" 201 -
